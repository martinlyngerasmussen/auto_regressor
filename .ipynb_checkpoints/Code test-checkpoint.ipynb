# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit
import warnings
warnings.filterwarnings('ignore')
from stargazer.stargazer import Stargazer, LineLocation

from experimentation import data_preparation_splits, regression_OLS, full_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = regression_OLS(file_location = "uk_data.csv", splits = 3, lags = 2, train_share = 0.9, p_cutoff = 0.2)

# %%
full_df = full_df(file_location = "uk_data.csv", lags = 5)

# %%
full_df.tail()
# Out:
#             const       gdp  wage_growth  gdp_lag1  wage_growth_lag1  \
# date
# 2023-01-31    1.0  0.490677     0.474684 -0.293542          0.476948
# 2023-02-28    1.0  0.195312     0.787402  0.490677          0.474684
# 2023-03-31    1.0 -0.292398     0.625000  0.195312          0.787402
# 2023-04-30    1.0  1.000000     0.662500 -0.292398          0.625000
# 2023-05-31    1.0       NaN     1.662500  1.000000          0.662500
#
#             gdp_lag2  wage_growth_lag2  gdp_lag3  wage_growth_lag3  gdp_lag4  \
# date
# 2023-01-31  0.097943          0.479233  0.591133          0.805153 -0.587659
# 2023-02-28 -0.293542          0.476948  0.097943          0.479233  0.591133
# 2023-03-31  0.490677          0.474684 -0.293542          0.476948  0.097943
# 2023-04-30  0.195312          0.787402  0.490677          0.474684 -0.293542
# 2023-05-31 -0.292398          0.625000  0.195312          0.787402  0.490677
#
#             wage_growth_lag4  gdp_lag5  wage_growth_lag5
# date
# 2023-01-31          0.323102  0.098039          0.814332
# 2023-02-28          0.805153 -0.587659          0.323102
# 2023-03-31          0.479233  0.591133          0.805153
# 2023-04-30          0.476948  0.097943          0.479233
# 2023-05-31          0.474684 -0.293542          0.476948

# %%
df[2]
# Out:
# <table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: gdp</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">split_1: 31/03/2005 to 30/06/2010</td><td colspan="1">split_2: 31/05/2011 to 31/08/2016</td><td colspan="1">split_3: 31/07/2017 to 30/09/2022</td><td colspan="1">Full sample</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">const</td><td></td><td>0.259<sup>***</sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.042)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">gdp_lag1</td><td></td><td>-0.471<sup>***</sup></td><td>0.455<sup>***</sup></td><td>0.402<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.130)</td><td>(0.134)</td><td>(0.131)</td></tr>
# <tr><td style="text-align:left">gdp_lag2</td><td></td><td></td><td>-0.422<sup>***</sup></td><td>-0.332<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.111)</td><td>(0.137)</td></tr>
# <tr><td style="text-align:left">wage_growth</td><td></td><td></td><td>0.728<sup>*</sup></td><td>0.299<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.403)</td><td>(0.181)</td></tr>
# <tr><td style="text-align:left">wage_growth_lag1</td><td>0.142<sup>***</sup></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.032)</td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">wage_growth_lag2</td><td>-0.092<sup>*</sup></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.050)</td><td></td><td></td><td></td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>64</td><td>64</td><td>63</td><td>214</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.109</td><td>0.234</td><td>0.305</td><td>0.212</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.081</td><td>0.222</td><td>0.271</td><td>0.201</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.583 (df=62)</td><td>0.472 (df=62)</td><td>2.723 (df=60)</td><td>1.603 (df=211)</td></tr><tr><td style="text-align: left">F Statistic</td><td>13.923<sup>***</sup> (df=2; 62)</td><td>13.228<sup>***</sup> (df=1; 62)</td><td>7.087<sup>***</sup> (df=3; 60)</td><td>3.707<sup>**</sup> (df=3; 211)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %%
df[3].tail(24).plot();

# %%
print(df[0])
print(df[1])
df[2]
print(df[3])
# Out:
# +------------------------------------------------------+
# | *** OUT OF SAMPLE PERFORMANCE ACROSS SUB-PERIODS *** |
# +------------+------------+------------+---------------+
# |            |   Sample 1 |   Sample 2 |      Sample 3 |
# +------------+------------+------------+---------------+
# | R2         |     0.0671 |    -0.0859 |       -0.8153 |
# | Mae        |     0.3373 |     0.2831 |        0.4736 |
# | Mse        |     0.1617 |     0.1111 |        0.3507 |
# | Rmse       |     0.4021 |     0.3333 |        0.5922 |
# | Start Date | 31/07/2010 | 30/09/2016 |    31/10/2022 |
# | End Date   | 28/02/2011 | 30/04/2017 |    30/04/2023 |
# +------------+------------+------------+---------------+
#             const  split_1_y_fitted  split_2_y_fitted  split_3_y_fitted
# date
# 2005-07-31    1.0         -0.024394               NaN               NaN
# 2005-08-31    1.0          0.112065               NaN               NaN
# 2005-09-30    1.0          0.038197               NaN               NaN
# 2005-10-31    1.0         -0.035644               NaN               NaN
# 2005-11-30    1.0          0.012727               NaN               NaN
# ...           ...               ...               ...               ...
# 2023-01-31    1.0               NaN               NaN               NaN
# 2023-02-28    1.0               NaN               NaN               NaN
# 2023-03-31    1.0               NaN               NaN               NaN
# 2023-04-30    1.0               NaN               NaN               NaN
# 2023-05-31    1.0               NaN               NaN               NaN
#
# [215 rows x 4 columns]
#             split_1_y_fitted  split_2_y_fitted  split_3_y_fitted  \
# date
# 2005-07-31         -0.024394           0.18189          0.216767
# 2005-08-31          0.112065           0.18189          0.129263
# 2005-09-30          0.038197           0.18189          0.000000
# 2005-10-31         -0.035644           0.18189          0.214647
# 2005-11-30          0.012727           0.18189         -0.128006
# ...                      ...               ...               ...
# 2023-01-31          0.023395           0.18189         -0.103081
# 2023-02-28          0.023285           0.18189          0.172308
# 2023-03-31          0.067884           0.18189          0.068587
# 2023-04-30          0.015920           0.18189         -0.102679
# 2023-05-31          0.036257           0.18189          0.351163
#
#             y_fitted_ave         y
# date
# 2005-07-31      0.199329  0.368098
# 2005-08-31      0.155576  0.000000
# 2005-09-30      0.090945  0.611247
# 2005-10-31      0.198269 -0.364520
# 2005-11-30      0.026942  1.097561
# ...                  ...       ...
# 2023-01-31      0.039404  0.490677
# 2023-02-28      0.177099  0.195312
# 2023-03-31      0.125238 -0.292398
# 2023-04-30      0.039605  1.000000
# 2023-05-31      0.266527       NaN
#
# [215 rows x 5 columns]

# %%
df[3].plot();
