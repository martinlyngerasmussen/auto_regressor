# %% [markdown]
# ### Auto regressor

# %%
# %load_ext autoreload
# %autoreload 2

from auto_regressor import auto_regressor

# %%
params = {
    "file_location": "uk_data.csv", ## a dummy dataset with monthly UK GDP, retail sales and wage growth
    "lags": 5, ## how many lags of X and Y to include
    "splits": 2,    ## how many subsets of the data to evaluate the relationship across. 
                    ## The prediction is still done using all available data, but the
                    ## splits are used to evaluate how robustness the relationship is.]
                    ## Predictions using full sample are only done if the end date of
                    ## all the predictors is later than the end date of Y
                    
    "train_share": 0.9, ## share of the data (for each split) to fit the model on
    "vif_threshold": 10, ## threshold value to remove colinear variables
    "p_cutoff": 0.05, ## p cut-off for backwards elimination of variables
    "show_removed_features": False
}

run = auto_regressor(**params)
# Out:
# #############################################
# PREDICTION
# #############################################
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: gdp</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">apr_2020</td><td>-10.223<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.969)</td></tr>
# <tr><td style="text-align:left">gdp_lag2</td><td>0.332<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.036)</td></tr>
# <tr><td style="text-align:left">gdp_lag3</td><td>0.145<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.057)</td></tr>
# <tr><td style="text-align:left">gdp_lag4</td><td>-0.124<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.028)</td></tr>
# <tr><td style="text-align:left">jun_2020</td><td>9.699<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.060)</td></tr>
# <tr><td style="text-align:left">mar_2020</td><td>-6.552<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.544)</td></tr>
# <tr><td style="text-align:left">retail_sales_lag3</td><td>0.113<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.041)</td></tr>
# <tr><td style="text-align:left">retail_sales_lag5</td><td>0.164<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.040)</td></tr>
# <tr><td style="text-align:left">retail_sales_squared_sign_kept</td><td>0.039<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.004)</td></tr>
# <tr><td style="text-align:left">retail_sales_squared_sign_kept_lag3</td><td>-0.037<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.006)</td></tr>
# <tr><td style="text-align:left">retail_sales_squared_sign_kept_lag5</td><td>-0.021<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.004)</td></tr>
# <tr><td style="text-align:left">wage_growth_lag1</td><td>0.084<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.040)</td></tr>
#
# <td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>215</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.916</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.911</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.534 (df=203)</td></tr><tr><td style="text-align: left">F Statistic</td><td>184.252<sup>***</sup> (df=12; 203)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="1" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
#             y_actual  y_fitted_split_b6
# date
# 2023-02-28  0.195312           0.012657
# 2023-03-31 -0.292398           0.285804
# 2023-04-30  1.000000           0.286960
# 2023-05-31       NaN          -0.157175
# 2023-06-30       NaN           0.534006
#
# #############################################
# EXPLORATORY ANALYSIS
# #############################################
#
# Target variable selected: gdp
#
# Correlation matrix:
# <style type="text/css">
# #T_bc2a7_row0_col0, #T_bc2a7_row1_col1, #T_bc2a7_row2_col2, #T_bc2a7_row3_col3, #T_bc2a7_row4_col4, #T_bc2a7_row5_col5, #T_bc2a7_row6_col6, #T_bc2a7_row7_col7, #T_bc2a7_row8_col8, #T_bc2a7_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bc2a7_row0_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_bc2a7_row0_col2, #T_bc2a7_row1_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_bc2a7_row0_col3, #T_bc2a7_row0_col5, #T_bc2a7_row0_col6, #T_bc2a7_row1_col4, #T_bc2a7_row2_col8, #T_bc2a7_row3_col7, #T_bc2a7_row4_col3, #T_bc2a7_row4_col7, #T_bc2a7_row5_col2, #T_bc2a7_row5_col3, #T_bc2a7_row5_col7, #T_bc2a7_row6_col0, #T_bc2a7_row6_col1, #T_bc2a7_row6_col3, #T_bc2a7_row6_col7, #T_bc2a7_row6_col9, #T_bc2a7_row7_col3, #T_bc2a7_row8_col3, #T_bc2a7_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bc2a7_row0_col4, #T_bc2a7_row2_col7 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_bc2a7_row0_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_bc2a7_row0_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_bc2a7_row0_col9 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_bc2a7_row1_col0 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_bc2a7_row1_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_bc2a7_row1_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_bc2a7_row1_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_bc2a7_row1_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_bc2a7_row1_col8 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_bc2a7_row1_col9 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_bc2a7_row2_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_bc2a7_row2_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_bc2a7_row2_col3, #T_bc2a7_row9_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_bc2a7_row2_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_bc2a7_row2_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_bc2a7_row2_col6, #T_bc2a7_row4_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_bc2a7_row2_col9 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_bc2a7_row3_col0, #T_bc2a7_row3_col6, #T_bc2a7_row4_col6, #T_bc2a7_row5_col6, #T_bc2a7_row7_col6, #T_bc2a7_row8_col6 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_bc2a7_row3_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_bc2a7_row3_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_bc2a7_row3_col4, #T_bc2a7_row5_col4, #T_bc2a7_row6_col4, #T_bc2a7_row7_col4, #T_bc2a7_row8_col4, #T_bc2a7_row9_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_bc2a7_row3_col5, #T_bc2a7_row4_col5, #T_bc2a7_row6_col5, #T_bc2a7_row7_col5, #T_bc2a7_row8_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_bc2a7_row3_col8, #T_bc2a7_row4_col8, #T_bc2a7_row5_col8, #T_bc2a7_row6_col8, #T_bc2a7_row7_col8, #T_bc2a7_row9_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_bc2a7_row3_col9 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_bc2a7_row4_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_bc2a7_row4_col2, #T_bc2a7_row6_col2, #T_bc2a7_row8_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_bc2a7_row4_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_bc2a7_row5_col0, #T_bc2a7_row9_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_bc2a7_row5_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_bc2a7_row5_col9 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bc2a7_row7_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_bc2a7_row7_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_bc2a7_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_bc2a7_row7_col9 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_bc2a7_row8_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_bc2a7_row8_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_bc2a7_row8_col9 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_bc2a7_row9_col0 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_bc2a7_row9_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_bc2a7_row9_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_bc2a7_row9_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_bc2a7_row9_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# </style>
# <table id="T_bc2a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc2a7_level0_col0" class="col_heading level0 col0" >gdp</th>
#       <th id="T_bc2a7_level0_col1" class="col_heading level0 col1" >retail_sales</th>
#       <th id="T_bc2a7_level0_col2" class="col_heading level0 col2" >wage_growth</th>
#       <th id="T_bc2a7_level0_col3" class="col_heading level0 col3" >jan_2020</th>
#       <th id="T_bc2a7_level0_col4" class="col_heading level0 col4" >feb_2020</th>
#       <th id="T_bc2a7_level0_col5" class="col_heading level0 col5" >mar_2020</th>
#       <th id="T_bc2a7_level0_col6" class="col_heading level0 col6" >apr_2020</th>
#       <th id="T_bc2a7_level0_col7" class="col_heading level0 col7" >may_2020</th>
#       <th id="T_bc2a7_level0_col8" class="col_heading level0 col8" >jun_2020</th>
#       <th id="T_bc2a7_level0_col9" class="col_heading level0 col9" >retail_sales_squared_sign_kept</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc2a7_level0_row0" class="row_heading level0 row0" >gdp</th>
#       <td id="T_bc2a7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bc2a7_row0_col1" class="data row0 col1" >0.752207</td>
#       <td id="T_bc2a7_row0_col2" class="data row0 col2" >0.143151</td>
#       <td id="T_bc2a7_row0_col3" class="data row0 col3" >-0.005117</td>
#       <td id="T_bc2a7_row0_col4" class="data row0 col4" >-0.020295</td>
#       <td id="T_bc2a7_row0_col5" class="data row0 col5" >-0.294650</td>
#       <td id="T_bc2a7_row0_col6" class="data row0 col6" >-0.755255</td>
#       <td id="T_bc2a7_row0_col7" class="data row0 col7" >0.076918</td>
#       <td id="T_bc2a7_row0_col8" class="data row0 col8" >0.366328</td>
#       <td id="T_bc2a7_row0_col9" class="data row0 col9" >0.831683</td>
#     </tr>
#     <tr>
#       <th id="T_bc2a7_level0_row1" class="row_heading level0 row1" >retail_sales</th>
#       <td id="T_bc2a7_row1_col0" class="data row1 col0" >0.752207</td>
#       <td id="T_bc2a7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bc2a7_row1_col2" class="data row1 col2" >0.145020</td>
#       <td id="T_bc2a7_row1_col3" class="data row1 col3" >0.054160</td>
#       <td id="T_bc2a7_row1_col4" class="data row1 col4" >-0.048489</td>
#       <td id="T_bc2a7_row1_col5" class="data row1 col5" >-0.174821</td>
#       <td id="T_bc2a7_row1_col6" class="data row1 col6" >-0.507752</td>
#       <td id="T_bc2a7_row1_col7" class="data row1 col7" >0.364185</td>
#       <td id="T_bc2a7_row1_col8" class="data row1 col8" >0.429650</td>
#       <td id="T_bc2a7_row1_col9" class="data row1 col9" >0.884879</td>
#     </tr>
#     <tr>
#       <th id="T_bc2a7_level0_row2" class="row_heading level0 row2" >wage_growth</th>
#       <td id="T_bc2a7_row2_col0" class="data row2 col0" >0.143151</td>
#       <td id="T_bc2a7_row2_col1" class="data row2 col1" >0.145020</td>
#       <td id="T_bc2a7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bc2a7_row2_col3" class="data row2 col3" >0.032866</td>
#       <td id="T_bc2a7_row2_col4" class="data row2 col4" >-0.018345</td>
#       <td id="T_bc2a7_row2_col5" class="data row2 col5" >-0.234395</td>
#       <td id="T_bc2a7_row2_col6" class="data row2 col6" >-0.018345</td>
#       <td id="T_bc2a7_row2_col7" class="data row2 col7" >0.021007</td>
#       <td id="T_bc2a7_row2_col8" class="data row2 col8" >-0.018345</td>
#       <td id="T_bc2a7_row2_col9" class="data row2 col9" >0.088945</td>
#     </tr>
#     <tr>
#       <th id="T_bc2a7_level0_row3" class="row_heading level0 row3" >jan_2020</th>
#       <td id="T_bc2a7_row3_col0" class="data row3 col0" >-0.005117</td>
#       <td id="T_bc2a7_row3_col1" class="data row3
# ############################################################
# ROBUSTNESS: OUT-OF-SAMPLE SUMMARY STATISTICS ACROSS SPLITS
# ############################################################
#                         Split 1           Split 2
# R2                    -0.166495         -0.369189
# MAE                    0.316238           0.51389
# MSE                    0.130144          0.330947
# RMSE                   0.360755           0.57528
# Sample period  Sep-13 to Mar-14  Dec-22 to Apr-23
# Sample length                 7                 5
# Split ID                     I2                c8
# #############################################
# PART 3: ROBUSTNESS OF MODELS ACROSS SPLITS
# #############################################
# <table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable: gdp</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr>
# <tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">apr_2020</td><td></td><td>-3.705<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(1.053)</td></tr>
# <tr><td style="text-align:left">gdp_lag1</td><td>-0.319<sup>***</sup></td><td>0.225<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.096)</td><td>(0.032)</td></tr>
# <tr><td style="text-align:left">gdp_lag2</td><td></td><td>0.215<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.044)</td></tr>
# <tr><td style="text-align:left">gdp_lag3</td><td>0.233<sup>**</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.097)</td><td></td></tr>
# <tr><td style="text-align:left">gdp_lag4</td><td>0.232<sup>**</sup></td><td>-0.475<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.097)</td><td>(0.053)</td></tr>
# <tr><td style="text-align:left">gdp_lag5</td><td></td><td>0.377<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.048)</td></tr>
# <tr><td style="text-align:left">jun_2020</td><td></td><td>2.519<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(1.207)</td></tr>
# <tr><td style="text-align:left">mar_2020</td><td></td><td>-5.968<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.428)</td></tr>
# <tr><td style="text-align:left">retail_sales_lag5</td><td>0.147<sup>**</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.062)</td><td></td></tr>
# <tr><td style="text-align:left">retail_sales_squared_sign_kept</td><td></td><td>0.061<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.004)</td></tr>
# <tr><td style="text-align:left">retail_sales_squared_sign_kept_lag4</td><td></td><td>0.030<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.004)</td></tr>
# <tr><td style="text-align:left">retail_sales_squared_sign_kept_lag5</td><td></td><td>-0.016<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.003)</td></tr>
# <tr><td style="text-align:left">wage_growth_lag1</td><td>0.141<sup>**</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.063)</td><td></td></tr>
# <tr><td style="text-align:left">wage_growth_lag5</td><td></td><td>0.243<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.052)</td></tr>
#
# <td colspan="3" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>94</td><td>94</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.247</td><td>0.978</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.204</td><td>0.975</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.579 (df=89)</td><td>0.416 (df=83)</td></tr><tr><td style="text-align: left">F Statistic</td><td>5.830<sup>***</sup> (df=5; 89)</td><td>330.105<sup>***</sup> (df=11; 83)</td></tr>
# <tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="2" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# #########################################################################################
# PART 4: ROBUSTNESS OF PERFORMANCE: IN-SAMPLE VS. OUT-OF-SAMPLE PERFORMANCE ACROSS SPLITS
# #########################################################################################
